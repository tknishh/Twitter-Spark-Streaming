# %%
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.sql import SQLContext
from pyspark.sql.functions import desc

sc = SparkContext()

ssc = StreamingContext(sc, 10)
sqlcontext = SQLContext(sc)
socket_stream = ssc.socketTextStream('127.0.0.1', 5554)
lines = socket_stream.window(20)
from collections import namedtuple
fields = ('tags',"count")
Tweet = namedtuple ('Tweet', fields)
( lines.flatMap( lambda text: text.split( " " ) )                 # Splits to a list
  .filter( lambda word: word.lower().startswith("#") )            # Checks for hashtag calls
  .map( lambda word: ( word.lower(), 1 ) )                        # Lower cases the word
  .reduceByKey( lambda a, b: a + b )                              # Reduces
  .map( lambda rec: Tweet( rec[0], rec[1] ) )                     # Stores in a Tweet Object
  .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
  .limit(10).registerTempTable("tweets") ) )                      # Registers to a table.
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/09/25 06:13:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/context.py:114: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning,

# %%
ssc.start()

# %%
import time
from IPython import display
import matplotlib.pyplot as plt
import seaborn as sns
# Only works for Jupyter Notebooks!
# %matplotlib inline
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]

# %%
count = 0
while count < 10:
    
    time.sleep( 3 )
    top_10_tweets = sqlcontext.sql( 'Select tag, count from tweets' )
    top_10_df = top_10_tweets.toPandas()
    display.clear_output(wait=True)
    plt.figure( figsize = ( 10, 8 ) )
#     sns.barplot(x='count',y='land_cover_specific', data=df, palette='Spectral')
    sns.barplot( x="count", y="tag", data=top_10_df)
    plt.show()
    count = count + 1
# Out:
# 22/09/25 06:14:03 ERROR JobScheduler: Error running job streaming job 1664086440000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# [Stage 0:>                                                          (0 + 1) / 1]
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipykernel_7771/3233657615.py in <module>
#       3
#       4     time.sleep( 3 )
# ----> 5     top_10_tweets = sqlcontext.sql( 'Select tag, count from tweets' )
#       6     top_10_df = top_10_tweets.toPandas()
#       7     display.clear_output(wait=True)
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/context.py in sql(self, sqlQuery)
#     543         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     544         """
# --> 545         return self.sparkSession.sql(sqlQuery)
#     546
#     547     def table(self, tableName: str) -> DataFrame:
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py in sql(self, sqlQuery, **kwargs)
#    1032             sqlQuery = formatter.format(sqlQuery, **kwargs)
#    1033         try:
# -> 1034             return DataFrame(self._jsparkSession.sql(sqlQuery), self)
#    1035         finally:
#    1036             if len(kwargs) > 0:
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
# -> 1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#    1324         for temp_arg in temp_args:
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     194                 # Hide where the exception came from that shows a non-Pythonic
#     195                 # JVM exception message.
# --> 196                 raise converted from None
#     197             else:
#     198                 raise
#
# AnalysisException: Table or view not found: tweets; line 1 pos 23;
# 'Project ['tag, 'count]
# +- 'UnresolvedRelation [tweets], [], false

# %%
ssc.stop()
# Out:
# 22/09/25 06:14:10 ERROR JobScheduler: Error running job streaming job 1664086450000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:14:20 ERROR JobScheduler: Error running job streaming job 1664086460000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:14:30 ERROR JobScheduler: Error running job streaming job 1664086470000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:14:40 ERROR JobScheduler: Error running job streaming job 1664086480000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:14:50 ERROR JobScheduler: Error running job streaming job 1664086490000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:15:00 ERROR JobScheduler: Error running job streaming job 1664086500000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:15:10 ERROR JobScheduler: Error running job streaming job 1664086510000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:15:20 ERROR JobScheduler: Error running job streaming job 1664086520000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:15:30 ERROR JobScheduler: Error running job streaming job 1664086530000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:15:40 ERROR JobScheduler: Error running job streaming job 1664086540000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:15:50 ERROR JobScheduler: Error running job streaming job 1664086550000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:16:00 ERROR JobScheduler: Error running job streaming job 1664086560000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:16:10 ERROR JobScheduler: Error running job streaming job 1664086570000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:16:20 ERROR JobScheduler: Error running job streaming job 1664086580000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# ...
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:18:30 ERROR JobScheduler: Error running job streaming job 1664086710000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:18:40 ERROR JobScheduler: Error running job streaming job 1664086720000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:18:50 ERROR JobScheduler: Error running job streaming job 1664086730000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# 22/09/25 06:19:00 ERROR JobScheduler: Error running job streaming job 1664086740000 ms.0
# org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/util.py", line 71, in call
#     r = self.func(t, *rdds)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/streaming/dstream.py", line 236, in func
#     return old_func(rdd)  # type: ignore[call-arg, arg-type]
#   File "/tmp/ipykernel_7771/455637378.py", line 20, in <lambda>
#     .foreachRDD( lambda rdd: rdd.toDF().sort( desc("count") )       # Sorts Them in a DF
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 102, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 895, in createDataFrame
#     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 934, in _create_dataframe
#     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 600, in _createFromRDD
#     struct = self._inferSchema(rdd, samplingRatio, names=schema)
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/sql/session.py", line 546, in _inferSchema
#     first = rdd.first()
#   File "/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pyspark/rdd.py", line 1906, in first
#     raise ValueError("RDD is empty")
# ValueError: RDD is empty
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.$anonfun$callForeachRDD$1$adapted(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$2(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:417)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.$anonfun$generateJob$1(ForEachDStream.scala:51)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.$anonfun$run$1(JobScheduler.scala:256)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:256)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:834)
# [Stage 0:>                                                          (0 + 1) / 1]
